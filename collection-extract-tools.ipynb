# %%
import csv
import json
import requests

# Build the URL
endpoint = 'https://www.loc.gov/free-to-use'
parameters = {
    'fo': 'json'
}
collection = 'libraries'

# Make the request
collection_list_response = requests.get(endpoint + '/' + collection, params=parameters)

# Verify the URL that was built
print("URL:", collection_list_response.url)
# Out:
# URL: https://www.loc.gov/free-to-use/libraries?fo=json

# %%
# Get the JSON
collection_json = collection_list_response.json()

# Look at the top-level keys
print("Top-level keys:", collection_json.keys())
# Out:
# Top-level keys: dict_keys(['breadcrumbs', 'content', 'description', 'disable_max_line_length', 'expert_resources', 'manifest', 'next', 'next_sibling', 'notice', 'options', 'pages', 'portal', 'portal_label', 'previous', 'previous_sibling', 'site_type', 'timestamp', 'title', 'type', 'ui2'])

# %%
# The items are at: content -> set -> items
items = collection_json['content']['set']['items']

print(f"Found {len(items)} items")

# Look at the first item
print("\nFirst item:")
print(items[0])
# Out:
# Found 62 items
#
# First item:
# {'image': '/static/portals/free-to-use/public-domain/libraries/libraries-1.jpg', 'link': '/resource/cph.3f05183/', 'title': 'For greater knowledge, on more subjects, use your library more often. Illinois WPA Arts Project, 1936-1941. Prints & Photographs Division'}

# %%
# Create the path for the CSV file
collection_set_list = 'ftu-libraries-set-list.csv'
headers = ['image', 'link', 'title']

# Write to CSV
with open(collection_set_list, 'w', encoding='utf-8', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=headers)
    writer.writeheader()
    
    for item in collection_json['content']['set']['items']:
        # Clean up errant spaces in the title fields
        item['title'] = item['title'].rstrip()
        writer.writerow(item)
    
    print(f'✓ Wrote {len(collection_json["content"]["set"]["items"])} items to {collection_set_list}')
# Out:
# ✓ Wrote 62 items to ftu-libraries-set-list.csv

# %%
# Save the full collection data to a JSON file
json_file_path = 'ftu-libraries-set-info.json'

with open(json_file_path, 'w', encoding='utf-8') as f:
    json.dump(collection_json, f, indent=2, ensure_ascii=False)

print(f"✓ Saved full collection data to {json_file_path}")
# Out:
# ✓ Saved full collection data to ftu-libraries-set-info.json

# %%
# Read and display the CSV file to verify
with open(collection_set_list, 'r', encoding='utf-8') as f:
    csv_reader = csv.DictReader(f)
    items = list(csv_reader)
    print(f"Total items in CSV: {len(items)}")
    print("\nFirst 3 items:")
    for i, item in enumerate(items[:3]):
        print(f"\nItem {i+1}:")
        print(f"  Title: {item['title']}")
        print(f"  Link: {item['link']}")
# Out:
# Total items in CSV: 62
#
# First 3 items:
#
# Item 1:
#   Title: For greater knowledge, on more subjects, use your library more often. Illinois WPA Arts Project, 1936-1941. Prints & Photographs Division
#   Link: /resource/cph.3f05183/
#
# Item 2:
#   Title: Noyes Library for Young Children. Kensington, Maryland. Photo by Carol M. Highsmith,  2011. Prints & Photographs Division
#   Link: /resource/highsm.20336/
#
# Item 3:
#   Title: Bethune-Cookman College. Students in the library reading room, Daytona Beach, Florida. Gordon Parks, 1943. Prints & Photographs Division
#   Link: /resource/fsa.8d24709/

# %%
import csv
import json
import requests
import os
import time
from os.path import join
import glob

# %%
# Create item-metadata directory if it doesn't exist
item_metadata_directory = 'item-metadata'

if os.path.isdir(item_metadata_directory):
    print(f"Directory exists: {item_metadata_directory}")
else:
    os.mkdir(item_metadata_directory)
    print(f"✓ Created directory: {item_metadata_directory}")
# Out:
# Directory exists: item-metadata

# %%
def regenerate_collection_list(collection_csv):
    """
    Reads a CSV file and returns the data as a list of dictionaries.
    
    Parameters:
    collection_csv (str): The path to the CSV file

    Returns:
    list: A list of dictionaries where each dict represents one item
    """

    coll_items = list()

    with open(collection_csv, 'r', newline='', encoding='utf-8') as f:
        data = csv.DictReader(f)

        for row in data:
            row_dict = dict()
            for field in data.fieldnames:
                row_dict[field] = row[field]
            coll_items.append(row_dict)

        return coll_items

# Load your collection list
collection_csv = 'ftu-libraries-set-list.csv'
collection_set_list = regenerate_collection_list(collection_csv)

print(f"✓ Loaded {len(collection_set_list)} items from CSV")
# Out:
# ✓ Loaded 62 items from CSV

# %%
# Set up the base URL and parameters
baseURL = 'https://www.loc.gov'
parameters = {
    'fo': 'json'
}

# Set up tracking variables
item_count = 0
error_count = 0
file_count = 0

data_directory = '.'  # Current directory
item_metadata_directory = 'item-metadata'
item_metadata_file_prefix = 'item_metadata'
json_suffix = '.json'

print("Starting to harvest item metadata...\n")

# Loop through each item in your collection list
for item in collection_set_list:
    item_link = item['link']
    
    # Skip header row or empty links
    if item_link == 'link' or not item_link:
        continue
    
    # Extract short ID from the link
    # Example: '/resource/cph.3f05183/' -> 'cph'
    # Using index [2] gets the 3rd element when split by '/'
    short_ID = item_link.split('/')[2]
    
    # Build full URL
    full_url = baseURL + item_link
    
    print(f"Requesting: {full_url}")
    
    try:
        # Request the item metadata with JSON parameter
        response = requests.get(full_url, params=parameters, timeout=20)
        print(f"  Status: {response.status_code}")
        
        item_count += 1
        
        # ADD DELAY TO AVOID RATE LIMITING - THIS IS KEY!
        time.sleep(1.0)
        
        # Check status code
        if response.status_code != 200:
            print(f"  ✗ Status code {response.status_code}")
            error_count += 1
            continue
        
        # Try to parse JSON
        try:
            item_metadata = response.json()
        except:
            print(f"  ✗ Could not parse JSON")
            error_count += 1
            continue
        
        # Check for 'item' key in response
        if 'item' not in item_metadata:
            print(f"  ✗ No 'item' key in response")
            error_count += 1
            continue
        
        # Save to file
        output_file = os.path.join(item_metadata_directory, 
                                   item_metadata_file_prefix + '-' + short_ID + json_suffix)
        
        with open(output_file, 'w', encoding='utf-8') as json_file:
            json.dump(item_metadata['item'], json_file, ensure_ascii=False)
            file_count += 1
            print(f"  ✓ Saved: {output_file}")
    
    except Exception as e:
        print(f"  ✗ Error: {str(e)}")
        error_count += 1

# Print summary
print("\n" + "="*60)
print("METADATA HARVEST SUMMARY")
print("="*60)
print(f"Items requested: {item_count}")
print(f"Errors: {error_count}")
print(f"Files saved: {file_count}")
print("="*60)
# Out:
# Starting to harvest item metadata...
#
# Requesting: https://www.loc.gov/resource/cph.3f05183/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-cph.3f05183.json
# Requesting: https://www.loc.gov/resource/highsm.20336/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.20336.json
# Requesting: https://www.loc.gov/resource/fsa.8d24709/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-fsa.8d24709.json
# Requesting: https://www.loc.gov/resource/highsm.36052/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.36052.json
# Requesting: https://www.loc.gov/resource/highsm.51772/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.51772.json
# Requesting: https://www.loc.gov/resource/cph.3b43255/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-cph.3b43255.json
# Requesting: https://www.loc.gov/resource/highsm.20483/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.20483.json
# Requesting: https://www.loc.gov/resource/highsm.29207/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.29207.json
# Requesting: https://www.loc.gov/resource/fsa.8b32222/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-fsa.8b32222.json
# Requesting: https://www.loc.gov/resource/highsm.64003/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.64003.json
# Requesting: https://www.loc.gov/resource/ppmsca.15412/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-ppmsca.15412.json
# Requesting: https://www.loc.gov/resource/highsm.49335/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.49335.json
# Requesting: https://www.loc.gov/resource/highsm.20497/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.20497.json
# Requesting: https://www.loc.gov/resource/npcc.28724/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-npcc.28724.json
# Requesting: https://www.loc.gov/resource/ds.06560/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-ds.06560.json
# Requesting: https://www.loc.gov/resource/hhh.hi0135.photos
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-hhh.hi0135.photos.json
# Requesting: https://www.loc.gov/resource/cph.3f05168/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-cph.3f05168.json
# Requesting: https://www.loc.gov/resource/ppmsca.15375/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-ppmsca.15375.json
# Requesting: https://www.loc.gov/resource/highsm.53335/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.53335.json
# Requesting: https://www.loc.gov/resource/hhh.ks0072.photos/?sp=2
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-hhh.ks0072.photos.json
# Requesting: https://www.loc.gov/resource/highsm.34640/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.34640.json
# Requesting: https://www.loc.gov/resource/ppmsca.17588/
#   Status: 403
#   ✗ Status code 403
# Requesting: https://www.loc.gov/resource/ppmsca.18016/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-ppmsca.18016.json
# Requesting: https://www.loc.gov/resource/hhh.me0057.photos/?sp=1
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-hhh.me0057.photos.json
# Requesting: https://www.loc.gov/resource/highsm.41101/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.41101.json
# Requesting: https://www.loc.gov/resource/det.4a17925/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-det.4a17925.json
# Requesting: https://www.loc.gov/resource/ppmsca.15426/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-ppmsca.15426.json
# Requesting: https://www.loc.gov/resource/ppmscd.00084/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-ppmscd.00084.json
# Requesting: https://www.loc.gov/resource/highsm.18384/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.18384.json
# Requesting: https://www.loc.gov/resource/g3851e.ct006252/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-g3851e.ct006252.json
# Requesting: https://www.loc.gov/resource/ppmsca.35590/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-ppmsca.35590.json
# Requesting: https://www.loc.gov/resource/hhh.il0998.sheet/?sp=1
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-hhh.il0998.sheet.json
# Requesting: https://www.loc.gov/resource/hhh.ok0012.sheet/?sp=8&q=hhh.ok0012
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-hhh.ok0012.sheet.json
# Requesting: https://www.loc.gov/resource/hhh.sc0767.photos/?sp=1
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-hhh.sc0767.photos.json
# Requesting: https://www.loc.gov/resource/hhh.nj0089.photos/?sp=4
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-hhh.nj0089.photos.json
# Requesting: https://www.loc.gov/resource/highsm.31350/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.31350.json
# Requesting: https://www.loc.gov/resource/hhh.ri0071.photos/?sp=8
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-hhh.ri0071.photos.json
# Requesting: https://www.loc.gov/resource/highsm.48241/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.48241.json
# Requesting: https://www.loc.gov/resource/det.4a23603/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-det.4a23603.json
# Requesting: https://www.loc.gov/resource/highsm.04362/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.04362.json
# Requesting: https://www.loc.gov/resource/hhh.dc0121.photos/?sp=24
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-hhh.dc0121.photos.json
# Requesting: https://www.loc.gov/resource/ppbd.00600/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-ppbd.00600.json
# Requesting: https://www.loc.gov/resource/fsa.8b14169/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-fsa.8b14169.json
# Requesting: https://www.loc.gov/resource/highsm.32720/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.32720.json
# Requesting: https://www.loc.gov/resource/fsa.8c22565/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-fsa.8c22565.json
# Requesting: https://www.loc.gov/resource/mrg.00785/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-mrg.00785.json
# Requesting: https://www.loc.gov/resource/hhh.ak0345.photos/?sp=2
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-hhh.ak0345.photos.json
# Requesting: https://www.loc.gov/resource/highsm.43863/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.43863.json
# Requesting: https://www.loc.gov/resource/highsm.42123/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.42123.json
# Requesting: https://www.loc.gov/resource/cph.3c18157/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-cph.3c18157.json
# Requesting: https://www.loc.gov/resource/ds.06507/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-ds.06507.json
# Requesting: https://www.loc.gov/resource/highsm.24333/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.24333.json
# Requesting: https://www.loc.gov/resource/mrg.00788/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-mrg.00788.json
# Requesting: https://www.loc.gov/resource/highsm.20216/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.20216.json
# Requesting: https://www.loc.gov/resource/cph.3b41963/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-cph.3b41963.json
# Requesting: https://www.loc.gov/resource/mrg.00432/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-mrg.00432.json
# Requesting: https://www.loc.gov/resource/cph.3b39859/
#   Status: 403
#   ✗ Status code 403
# Requesting: https://www.loc.gov/resource/highsm.60215/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.60215.json
# Requesting: https://www.loc.gov/resource/ppmsca.15419/
#   Status: 403
#   ✗ Status code 403
# Requesting: https://www.loc.gov/resource/highsm.50410/
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.50410.json
# Requesting: https://www.loc.gov/resource/hhh.nv0134.photos
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-hhh.nv0134.photos.json
# Requesting: https://www.loc.gov/resource/highsm.18402
#   Status: 200
#   ✓ Saved: item-metadata/item_metadata-highsm.18402.json
#
# ============================================================
# METADATA HARVEST SUMMARY
# ============================================================
# Items requested: 62
# Errors: 3
# Files saved: 59
# ============================================================

# %%
# List all the metadata files created
metadata_files = glob.glob(os.path.join(item_metadata_directory, '*.json'))
print(f"\n✓ Total metadata files: {len(metadata_files)}")
print(f"(Requirement: at least 55 items)")

if len(metadata_files) >= 55:
    print("✓✓ MEETS REQUIREMENT!")
else:
    print(f"⚠ Below requirement by {55 - len(metadata_files)} items")

print("\nFirst 5 metadata files:")
for file in sorted(metadata_files)[:5]:
    print(f"  - {os.path.basename(file)}")
# Out:
# ✓ Total metadata files: 59
# (Requirement: at least 55 items)
# ✓✓ MEETS REQUIREMENT!
#
# First 5 metadata files:
#   - item_metadata-cph.3b41963.json
#   - item_metadata-cph.3b43255.json
#   - item_metadata-cph.3c18157.json
#   - item_metadata-cph.3f05168.json
#   - item_metadata-cph.3f05183.json

# %%
# Create the item-files directory if it doesn't exist
files_directory = 'item-files'

if os.path.isdir(files_directory):
    print(f"Directory exists: {files_directory}")
else:
    os.mkdir(files_directory)
    print(f"✓ Created directory: {files_directory}")
# Out:
# Directory exists: item-files

# %%
# Get list of all metadata files
search_for_metadata_here = os.path.join(item_metadata_directory)
metadata_file_list = glob.glob(search_for_metadata_here + '/*.json')

print(f"Found {len(metadata_file_list)} metadata files\n")

# Extract image URLs from each metadata file
collection_set_list_with_images = []

for item in metadata_file_list:
    with open(item, 'r', encoding='utf-8') as f:
        metadata = json.load(f)
        
        # Create a dictionary for this item
        item_metadata_dict = dict()
        item_metadata_dict['item_URI'] = metadata['id']
        
        try:
            item_metadata_dict['lccn'] = metadata['library_of_congress_control_number']
        except:
            item_metadata_dict['lccn'] = None
        
        item_metadata_dict['title'] = metadata['title']
        
        # Get the image URL - it's usually in image_url array
        # Use the last one (usually the largest)
        item_metadata_dict['image_URL_large'] = metadata['image_url'][-1]
        
        collection_set_list_with_images.append(item_metadata_dict)

print(f"✓ Extracted image URLs from {len(collection_set_list_with_images)} items")

# Show first item
if collection_set_list_with_images:
    print("\nFirst item:")
    print(collection_set_list_with_images[0])
# Out:
# Found 59 metadata files
#
# ✓ Extracted image URLs from 59 items
#
# First item:
# {'item_URI': 'http://www.loc.gov/item/97511671/', 'lccn': '97511671', 'title': 'Carnegie Library, Sheldon, Iowa', 'image_URL_large': 'https://tile.loc.gov/storage-services/service/pnp/cph/3c10000/3c18000/3c18100/3c18157v.jpg#h=824&w=1024'}

# %%
# Download images
img_file_prefix = 'img_'
item_count = 0
error_count = 0
file_count = 0

print("Starting image downloads...\n")

for item in collection_set_list_with_images:
    image_URL = item['image_URL_large']
    
    # Extract short ID from the URI
    # Example: '/resource/cph.3f05183/' -> 'cph'
    short_ID = item['item_URI'].split('/')[-2]
    
    print(f"Downloading: {image_URL}")
    
    try:
        response = requests.get(image_URL, timeout=10)
        item_count += 1
        
        if response.status_code == 200:
            # Save the image
            output_file = os.path.join(files_directory, f'{img_file_prefix}{short_ID}.jpg')
            
            with open(output_file, 'wb') as img_file:
                img_file.write(response.content)
            
            file_count += 1
            print(f"  ✓ Saved: {output_file}")
        else:
            print(f"  ✗ Status code {response.status_code}")
            error_count += 1
    
    except Exception as e:
        print(f"  ✗ Error: {str(e)}")
        error_count += 1

# Print summary
print("\n" + "="*60)
print("IMAGE DOWNLOAD SUMMARY")
print("="*60)
print(f"Images requested: {item_count}")
print(f"Errors: {error_count}")
print(f"Files downloaded: {file_count}")
print("="*60)
# Out:
# Starting image downloads...
#
# Downloading: https://tile.loc.gov/storage-services/service/pnp/cph/3c10000/3c18000/3c18100/3c18157v.jpg#h=824&w=1024
#   ✓ Saved: item-files/img_97511671.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/ppbd/00600/00600v.jpg#h=1024&w=765
#   ✓ Saved: item-files/img_2015647967.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/mrg/00700/00785v.jpg#h=697&w=1024
#   ✓ Saved: item-files/img_2017702899.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05183v.jpg#h=1024&w=705
#   ✓ Saved: item-files/img_98508155.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:gmd:gmd385:g3851:g3851e:ct006252/full/pct:25/0/default.jpg#h=1205&w=1684
#   ✓ Saved: item-files/img_87694100.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:pnp:highsm:43800:43863/full/pct:25/0/default.jpg#h=2117&w=2822
#   ✓ Saved: item-files/img_2017880767.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/ppmsca/18000/18016v.jpg#h=755&w=1024
#   ✓ Saved: item-files/img_2008678216.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:pnp:highsm:20400:20497/full/pct:50/0/default.jpg#h=2395&w=2053
#   ✓ Saved: item-files/img_2012630178.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/fsa/8b14000/8b14100/8b14169v.jpg#h=783&w=1024
#   ✓ Saved: item-files/img_2017762724.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/ppmsca/35500/35590v.jpg#h=642&w=1024
#   ✓ Saved: item-files/img_96514755.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/mrg/00700/00788v.jpg#h=699&w=1024
#   ✓ Saved: item-files/img_2017702902.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:pnp:highsm:34600:34640/full/pct:25/0/default.jpg#h=1113&w=1602
#   ✓ Saved: item-files/img_2017685123.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:pnp:highsm:20300:20336/full/pct:25/0/default.jpg#h=829&w=1540
#   ✓ Saved: item-files/img_2012630017.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/fsa/8c22000/8c22500/8c22565v.jpg#h=787&w=1024
#   ✓ Saved: item-files/img_2017815837.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/cph/3b40000/3b41000/3b41900/3b41963v.jpg#h=823&w=1024
#   ✓ Saved: item-files/img_91787443.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/ppmsca/15400/15412v.jpg#h=779&w=1024
#   ✓ Saved: item-files/img_2007684172.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:pnp:highsm:32700:32720/full/pct:25/0/default.jpg#h=1029&w=1530
#   ✓ Saved: item-files/img_2015632735.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/mrg/00400/00432v.jpg#h=709&w=1024
#   ✓ Saved: item-files/img_2017702546.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/habshaer/hi/hi0100/hi0135/photos/058276pv.jpg#h=733&w=1024
#   ✓ Saved: item-files/img_hi0135.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/habshaer/il/il0900/il0998/sheet/00001v.jpg#h=678&w=1024
#   ✓ Saved: item-files/img_il0998.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/det/4a10000/4a17000/4a17900/4a17925v.jpg#h=814&w=1024
#   ✓ Saved: item-files/img_2016809661.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:pnp:highsm:24300:24333/full/pct:50/0/default.jpg#h=1514&w=1207
#   ✓ Saved: item-files/img_2013631511.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/ppmscd/00000/00084v.jpg#h=829&w=1024
#   ✓ Saved: item-files/img_2009632000.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/habshaer/ks/ks0000/ks0072/photos/069905pv.jpg#h=815&w=1024
#   ✓ Saved: item-files/img_ks0072.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/highsm/64000/64003v.jpg#h=768&w=1024
#   ✓ Saved: item-files/img_2020722343.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:pnp:highsm:41100:41101/full/pct:25/0/default.jpg#h=1448&w=2172
#   ✓ Saved: item-files/img_2016631919.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:pnp:highsm:31300:31350/full/pct:25/0/default.jpg#h=1228&w=1642
#   ✓ Saved: item-files/img_2015631425.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/habshaer/ok/ok0000/ok0012/photos/129399pv.jpg#h=833&w=1024
#   ✓ Saved: item-files/img_ok0012.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/habshaer/sc/sc0700/sc0767/color/571307cv.jpg#h=745&w=1024
#   ✓ Saved: item-files/img_sc0767.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/habshaer/ri/ri0000/ri0071/photos/144412pv.jpg#h=732&w=1024
#   ✓ Saved: item-files/img_ri0071.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/cph/3b40000/3b43000/3b43200/3b43255r.jpg#h=422&w=640
#   ✓ Saved: item-files/img_89710983.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/habshaer/me/me0000/me0057/photos/088141pv.jpg#h=814&w=1024
#   ✓ Saved: item-files/img_me0057.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:pnp:highsm:36000:36052/full/pct:25/0/default.jpg#h=1448&w=2172
#   ✓ Saved: item-files/img_2017686535.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/highsm/60200/60215v.jpg#h=741&w=1024
#   ✓ Saved: item-files/img_2020723718.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/cph/3f00000/3f05000/3f05100/3f05168v.jpg#h=1024&w=708
#   ✓ Saved: item-files/img_98508385.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/ds/06500/06507v.jpg#h=826&w=1024
#   ✓ Saved: item-files/img_2014650180.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/highsm/51700/51772v.jpg#h=570&w=1024
#   ✓ Saved: item-files/img_2018699890.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:pnp:highsm:18400:18402/full/pct:25/0/default.jpg#h=1024&w=1536
#   ✓ Saved: item-files/img_2013646484.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/ppmsca/15300/15375v.jpg#h=1024&w=823
#   ✓ Saved: item-files/img_2007684791.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/habshaer/nv/nv0100/nv0134/photos/043970pv.jpg#h=819&w=1024
#   ✓ Saved: item-files/img_nv0134.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:pnp:highsm:20200:20216/full/pct:25/0/default.jpg#h=772&w=1551
#   ✓ Saved: item-files/img_2012631625.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/highsm/49300/49335v.jpg#h=618&w=1024
#   ✓ Saved: item-files/img_2018663053.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:pnp:highsm:04300:04362/full/pct:25/0/default.jpg#h=1358&w=1810
#   ✓ Saved: item-files/img_2010630352.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/npcc/28700/28724v.jpg#h=788&w=1024
#   ✓ Saved: item-files/img_2016851550.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:pnp:highsm:29200:29207/full/pct:25/0/default.jpg#h=1840&w=1228
#   ✓ Saved: item-files/img_2014633407.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/det/4a20000/4a23000/4a23600/4a23603v.jpg#h=820&w=1024
#   ✓ Saved: item-files/img_2016815290.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/ds/06500/06560v.jpg#h=727&w=1024
#   ✓ Saved: item-files/img_2014647618.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/habshaer/ak/ak0300/ak0345/photos/033063pv.jpg#h=817&w=1024
#   ✓ Saved: item-files/img_ak0345.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/habshaer/nj/nj0000/nj0089/photos/107604pv.jpg#h=733&w=1024
#   ✓ Saved: item-files/img_nj0089.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:pnp:highsm:20400:20483/full/pct:25/0/default.jpg#h=1028&w=1536
#   ✓ Saved: item-files/img_2012630164.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/highsm/50400/50410v.jpg#h=558&w=1024
#   ✓ Saved: item-files/img_2018698612.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/fsa/8b32000/8b32200/8b32222v.jpg#h=1024&w=963
#   ✓ Saved: item-files/img_2017770391.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:pnp:highsm:18300:18384/full/pct:25/0/default.jpg#h=1940&w=2582
#   ✓ Saved: item-files/img_2013646466.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/ppmsca/15400/15426v.jpg#h=1024&w=822
#   ✓ Saved: item-files/img_2007682033.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:pnp:highsm:48200:48241/full/pct:25/0/default.jpg#h=2380&w=1945
#   ✓ Saved: item-files/img_2017884872.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/fsa/8d24000/8d24700/8d24709v.jpg#h=1024&w=976
#   ✓ Saved: item-files/img_2017843202.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/highsm/53300/53335v.jpg#h=1000&w=1024
#   ✓ Saved: item-files/img_2019631085.jpg
# Downloading: https://tile.loc.gov/image-services/iiif/service:pnp:highsm:42100:42123/full/pct:25/0/default.jpg#h=1978&w=1398
#   ✓ Saved: item-files/img_2016632941.jpg
# Downloading: https://tile.loc.gov/storage-services/service/pnp/habshaer/dc/dc0100/dc0121/color/376695cv.jpg#h=1024&w=752
#   ✓ Saved: item-files/img_dc0121.jpg
#
# ============================================================
# IMAGE DOWNLOAD SUMMARY
# ============================================================
# Images requested: 59
# Errors: 0
# Files downloaded: 59
# ============================================================

# %%
# List all the image files created
image_files = glob.glob(os.path.join(files_directory, '*.jpg'))
print(f"\n✓ Total image files: {len(image_files)}")

print("\nFirst 5 image files:")
for file in sorted(image_files)[:5]:
    file_size = os.path.getsize(file) / 1024  # KB
    print(f"  - {os.path.basename(file)} ({file_size:.1f} KB)")
# Out:
# ✓ Total image files: 59
#
# First 5 image files:
#   - img_2007682033.jpg (165.0 KB)
#   - img_2007684172.jpg (121.6 KB)
#   - img_2007684791.jpg (167.0 KB)
#   - img_2008678216.jpg (153.8 KB)
#   - img_2009632000.jpg (162.2 KB)

# %%
# Verify everything is in place
print("="*60)
print("FINAL VERIFICATION")
print("="*60)

# Check CSV file
if os.path.exists('ftu-libraries-set-list.csv'):
    with open('ftu-libraries-set-list.csv', 'r') as f:
        rows = len(f.readlines()) - 1  # Subtract header
    print(f"✓ CSV file exists ({rows} items)")
else:
    print("✗ CSV file MISSING")

# Check JSON file
if os.path.exists('ftu-libraries-set-info.json'):
    print(f"✓ Collection JSON file exists")
else:
    print("✗ Collection JSON file MISSING")

# Check metadata directory
metadata_files = glob.glob(os.path.join('item-metadata', '*.json'))
if metadata_files:
    print(f"✓ Metadata directory has {len(metadata_files)} files")
    if len(metadata_files) >= 55:
        print("  ✓✓ Meets minimum requirement (55+)")
else:
    print("✗ Metadata directory is empty")

# Check image directory
image_files = glob.glob(os.path.join('item-files', '*.jpg'))
if image_files:
    print(f"✓ Image directory has {len(image_files)} files")
    if len(image_files) >= 55:
        print("  ✓✓ Meets minimum requirement (55+)")
else:
    print("✗ Image directory is empty")

print("="*60)
print("✓ ASSIGNMENT COMPLETE!")
print("="*60)
# Out:
# ============================================================
# FINAL VERIFICATION
# ============================================================
# ✓ CSV file exists (62 items)
# ✓ Collection JSON file exists
# ✓ Metadata directory has 59 files
#   ✓✓ Meets minimum requirement (55+)
# ✓ Image directory has 59 files
#   ✓✓ Meets minimum requirement (55+)
# ============================================================
# ✓ ASSIGNMENT COMPLETE!
# ============================================================
